# %% [markdown]
# # Proje: Image Segmentation(Görüntü Bölümlendirmesi)

# %% [markdown]
# Görüntü Bölümlendirmesinin amacı, görüntünün piksel bazında bir maskesini döndürebilen bir Sinir Ağı eğitmektir.

# %% [markdown]
# ## 1. Kütüphanelerin Yüklenmesi

# %%
import tensorflow as tf
from tensorflow_examples.models.pix2pix import pix2pix
import tensorflow_datasets as tfds
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %% [markdown]
# Zaten Tensorflow'da bulunan Oxford-IIIT Pets veri setini kullanacağız

# %%
dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)
# Out:
# 2024-10-23 14:40:41.361357: W external/local_tsl/tsl/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "FAILED_PRECONDITION: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Could not resolve host: metadata.google.internal".
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/3680 [00:00<?, ? examples/s]
# Shuffling /Users/talipakhan/tensorflow_datasets/oxford_iiit_pet/incomplete.QTYMQ9_3.2.0/oxford_iiit_pet-train.…
# Generating test examples...:   0%|          | 0/3669 [00:00<?, ? examples/s]
# ...

# %% [markdown]
# Aşağıdaki kod basit bir görüntü büyütme işlemi gerçekleştirir. Tıpkı metin analizine dayalı herhangi bir makine öğrenmesi görevi yapmadan önce verileri hazırladığımız gibi.

# %%
def normalize(input_image, input_mask):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  input_mask -= 1
  return input_image, input_mask


@tf.function
def load_image_train(datapoint):
  input_image = tf.image.resize(datapoint['image'], (128, 128))
  input_mask = tf.image.resize(datapoint['segmentation_mask'], (128, 128))

  if tf.random.uniform(()) > 0.5:
    input_image = tf.image.flip_left_right(input_image)
    input_mask = tf.image.flip_left_right(input_mask)

  input_image, input_mask = normalize(input_image, input_mask)

  return input_image, input_mask
def load_image_test(datapoint):
  input_image = tf.image.resize(datapoint['image'], (128, 128))
  input_mask = tf.image.resize(datapoint['segmentation_mask'], (128, 128))

  input_image, input_mask = normalize(input_image, input_mask)

  return input_image, input_mask

# %% [markdown]
# Veri setinde zaten gerekli sayıda eğitim ve test setimiz var. Bu yüzden eğitim ve test setlerinin bu bölünmesini kullanmaya devam edeceğiz.

# %%
TRAIN_LENGTH = info.splits['train'].num_examples
BATCH_SIZE = 64
BUFFER_SIZE = 1000
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

train = dataset['train'].map(load_image_train, num_parallel_calls=tf.data.AUTOTUNE)
test = dataset['test'].map(load_image_test)

train_dataset = train.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = test.batch(BATCH_SIZE)

# %% [markdown]
# Şimdi verilerden bir görüntüye ve onun maskesine hızlıca bakalım

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input Image', 'True Mask', 'Predicted Mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
    plt.axis('off')
  plt.show()
  
  
for image, mask in train.take(1):
  sample_image, sample_mask = image, mask
display([sample_image, sample_mask])
# Out:
# 2024-10-23 14:48:20.574559: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Görüntü Segmentasyon Modelini Tanımlama

# %% [markdown]
# Burada kullanacağım model değiştirilmiş bir U-Net'tir. Bir U-Net bir kodlayıcı ve bir kod çözücü içerir. Sağlam özellikleri öğrenmek ve tüm eğitilebilir parametreleri azaltmak için önceden eğitilmiş bir model kodlayıcı olarak verimli bir şekilde kullanılabilir.

# %%
OUTPUT_CHANNELS = 3

# %% [markdown]
# Yukarıda da belirttiğim gibi, kodlayıcımız tf.keras.applications'da mevcut ve kullanıma hazır önceden eğitilmiş bir modeldir. Bu kodlayıcı, modelin ara katmanlarından bazı özel çıktılar içerir. Lütfen kodlayıcının eğitim süreci boyunca eğitilmeyeceğini unutmayın.

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[128, 128, 3], include_top=False)

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)

down_stack.trainable = False
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# Kod çözücü/yukarı örnekleyici, TensorFlow örneklerinde uygulanan bir dizi yukarı örnekleme bloğundan ibarettir

# %%
up_stack = [
    pix2pix.upsample(512, 3),  # 4x4 -> 8x8
    pix2pix.upsample(256, 3),  # 8x8 -> 16x16
    pix2pix.upsample(128, 3),  # 16x16 -> 32x32
    pix2pix.upsample(64, 3),   # 32x32 -> 64x64
]


def unet_model(output_channels):
  inputs = tf.keras.layers.Input(shape=[128, 128, 3])

  # Downsampling through the model
  skips = down_stack(inputs)
  x = skips[-1]
  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    concat = tf.keras.layers.Concatenate()
    x = concat([x, skip])

# This is the last layer of the model
  last = tf.keras.layers.Conv2DTranspose(
      output_channels, 3, strides=2,
      padding='same')  #64x64 -> 128x128

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# ## Görüntü Bölümlendirme Modelinin Eğitimi

# %%
model = unet_model(OUTPUT_CHANNELS)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Şimdi ilerlemeden önce eğitilmiş modelin ortaya çıkan çıktısına hızlıca bir bakalım

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# Eğitimden önce modeli deneyip ne tahmin ettiğini görelim

# %%
def create_mask(pred_mask):
  pred_mask = tf.argmax(pred_mask, axis=-1)
  pred_mask = pred_mask[..., tf.newaxis]
  return pred_mask[0]

def show_predictions(dataset=None, num=1):
  if dataset:
    for image, mask in dataset.take(num):
      pred_mask = model.predict(image)
      display([image[0], mask[0], create_mask(pred_mask)])
  else:
    display([sample_image, sample_mask,
             create_mask(model.predict(sample_image[tf.newaxis, ...]))])
show_predictions()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step

# %% [markdown]
# Şimdi, Görüntü Bölümlendirme modelinin eğitim sırasında nasıl geliştiğini gözlemleyelim. Bu görevi başarmak için, aşağıda bir geri çağırma işlevi tanımlanımlıyoruz. Geri çağırma işlevi, eğitim sırasında modelin performansını ölçmek için kullanılır.

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    clear_output(wait=True)
    show_predictions()
    print ('\nSample Prediction after epoch {}\n'.format(epoch+1))
    
    
EPOCHS = 20
VAL_SUBSPLITS = 5
VALIDATION_STEPS = info.splits['test'].num_examples//BATCH_SIZE//VAL_SUBSPLITS

model_history = model.fit(train_dataset, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=test_dataset,
                          callbacks=[DisplayCallback()])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Sample Prediction after epoch 20
#
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9361 - loss: 0.1410 - val_accuracy: 0.8918 - val_loss: 0.2929

# %% [markdown]
# Şimdi, modelin performansına hızlıca bir göz atalım

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

epochs = range(EPOCHS)

plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %% [markdown]
# ## Görüntü Bölümlendirmesini Kullanarak Tahminlerde Bulunmak

# %% [markdown]
# Bazı tahminlerde bulunalım. Zamandan tasarruf etmek amacıyla, dönem sayısı küçük tutuldu, ancak daha doğru sonuçlar elde etmek için bunu daha yüksek ayarlayabilirsiniz

# %%
show_predictions(test_dataset, 5)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step
# 2024-10-23 15:30:38.660119: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Sonuç:

# %% [markdown]
# Derin öğrenme ile görüntü segmentasyonu yapmak için bu projeyi gerçekleştidik. Bu teknoloji günümüzde çok popüler bir alandır. Görüntülerin segmentasyonu, görüntü analizi ve görüntü işlemede önemli bir adımdır. Görüntülerin segmentasyonu, insanların görsel olarak anlaması ve algılaması için önemlidir. Segmentasyon, görüntülerin parçalarını ayırmak ve bölümlerini tanımlamak için kullanılan bir yöntemdir. Otomotivden güvenliğe birçok alanda kullnılmaktadır.
